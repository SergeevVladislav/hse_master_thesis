# %%
import pandas as pd

# %%
def read_data(file):
    df = pd.read_excel(f"../data/fertility_rate/{file}")
    df = df.drop(labels=["Unnamed: 1"], axis=1)
    df = df.rename(columns={"Unnamed: 0": "region"})
    df_long = df.melt(
        id_vars='region',
        var_name='date',
        value_name=f'{file[:-4]}'
    )
    df_long['date'] = df_long['date'].astype(int)

    df_long = df_long.sort_values(['region', 'date'])
    df_long = df_long.dropna(subset=f'{file[:-4]}')
    df_long.region = df_long.region.str.strip()
    return df_long

# %%
import os

df_final = pd.DataFrame()
for filename in [file for file in os.listdir("../data/fertility_rate/") if "csv" not in file]:
    print(filename)
    dff = read_data(filename)
    if df_final.empty:
        df_final = dff
    else:
        df_final = pd.merge(df_final, dff, on=["date", "region"], how="inner")
# Out:
# fertility_rate_city.xls
# fertility_rate_all.xls
# fertility_rate_village.xls

# %%
lag_steps = [1, 3, 5]
factors = df_final.drop(labels=["region", "date"], axis=1).columns.tolist()

for factor in factors:
    for lag in lag_steps:
        df_final[f'{factor}_lag_{lag}'] = df_final.groupby('region')[factor].shift(lag)

# %%
df_final.to_csv("../data/fertility_rate/fertility_rate_features.csv", index=False)
