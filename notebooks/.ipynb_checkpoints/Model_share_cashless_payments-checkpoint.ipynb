# %%
import pandas as pd

pd.set_option("display.max_columns", 50)

# %%
target_df = pd.read_csv("../data/final_mart_30_04_8_35.csv")
target_df.head()
# Out:
#          date                 region  \
# 0  2013-10-01  Архангельская область
# 1  2013-10-01   Астраханская область
# 2  2013-10-01   Белгородская область
# 3  2013-10-01       Брянская область
# 4  2013-10-01   Владимирская область
#
#    Total number of banking system institutions  \
# 0                                        350.0
# 1                                        293.0
# 2                                        542.0
# 3                                        325.0
# 4                                        475.0
#
#    institutions of the Bank of Russia  credit institutions  \
# 0                                   8                    2
# 1                                   3                    5
# 2                                   4                    4
# 3                                   3                    0
# 4                                   6                    3
#
#    branches of credit organizations  additional offices  \
# 0                                23               184.0
# 1                                18               115.0
# 2                                12               163.0
# 3                                12               103.0
# 4                                13               203.0
#
#    Number of bank institutions per 1 million inhabitants  total_accounts  \
# 0                                              291.0              4304.1
# 1                                              289.0              3136.0
# 2                                              352.0              5113.9
# 3                                              259.0              3968.8
# 4                                              334.0              5613.8
#
#    total_in_credit_org  \
# 0               4303.5
# 1               3135.6
# 2               5113.3
# 3               3968.0
# 4               5613.4
#
#    clients-legal entities that are not credit institutions  \
# 0                                               40.6
# 1                                               27.4
# 2                                               45.0
# 3                                               20.5
# 4                                               41.7
#
#    individual clients  \
# 0              4262.8
# 1              3108.2
# 2              5068.4
# 3              3947.6
# 4              5571.7
#
#    The number of accounts opened by institutions of the banking system, per 1 resident, units.  \
# 0                                                3.6
# 1                                                3.1
# 2                                                3.3
# 3                                                3.2
# 4                                                3.9
#
#    number_of_new_remote_accounts  number_of_new_remote_accounts_individuals  \
# 0                          741.3                                      726.6
# 1                          519.3                                      508.1
# 2                          811.0                                      794.0
# 3                          561.6                                      557.6
# 4                          346.6                                      328.9
#
#    number_of_new_remote_accounts_individuals_with_internet  \
# 0                                                8.5
# 1                                               90.1
# 2                                              463.8
# 3                                               15.2
# 4                                              217.0
#
#    number_of_new_remote_accounts_individuals_with_sms  \
# 0                                               75.3
# 1                                               86.9
# 2                                              207.2
# 3                                              333.0
# 4                                              195.2
#
#    orders in electronic form total  orders in electronic form with internet  \
# 0                           3611.6                                   1396.7
# 1                           1051.9                                    279.1
# 2                           8688.4                                   1124.2
# 3                            743.0                                    228.3
# 4                           3021.3                                    956.9
#
#    payments orders  payments orders with internet  letter of credit  \
# 0           1628.8                         1393.5               0.0
# 1            453.6                          279.1               0.0
# 2           1422.0                         1109.3               0.0
# 3            400.6                          228.3               0.0
# 4           1669.7                          956.7               0.0
#
#    payment requirements  payment requirements with internet  \
# 0                   3.6                                 3.2
# 1                   0.8                                 0.0
# 2                  16.3                                14.9
# 3                  15.0                                 0.0
# 4                   0.3                                 0.3
#
#    collection orders  bank orders  volume orders in electronic form total  \
# 0               22.8       1956.5                                   196.9
# 1                9.5        588.0                                    98.5
# 2               46.0       7204.1                                   401.5
# 3               27.4        300.0                                    64.3
# 4               14.3       1337.0                                   163.3
#
#    volume orders in electronic form with internet  volume payments orders  \
# 0                                           172.3                   194.1
# 1                                            52.3                    97.5
# 2                                           295.1                   399.4
# 3                                            47.0                    63.0
# 4                                            87.8                   160.4
#
#    volume payments orders with internet  volume letter of credit  \
# 0                                 171.7                      0.0
# 1                                  52.3                      0.0
# 2                                 294.9                      0.0
# 3                                  47.0                      0.0
# 4                                  87.8                      0.0
#
#    volume payment requirements  volume payment requirements with internet  \
# 0                          0.7                                        0.6
# 1                          0.0                                        0.0
# 2                          0.3                                        0.2
# 3                          0.7                                        0.0
# 4                          0.0                                        0.0
#
#    volume collection orders  volume bank orders  orders amount  \
# 0                       0.4                 1.8          230.8
# 1                       0.1                 0.8          139.0
# 2                       0.4                 1.4          439.1
# 3                       0.2                 0.2          121.8
# 4                       0.1                 2.8          211.6
#
#    payment orders amount  payment requirements, collection orders amount  \
# 0                  220.6                                             2.2
# 1                  132.9                                             0.6
# 2                  430.3                                             0.9
# 3                  116.9                                             1.1
# 4                  201.6                                             1.7
#
#    letters of credit amount  checks amount  bank orders amount  \
# 0                       0.1            0.0                 3.0
# 1                       0.1            0.0                 1.4
# 2                       0.1            0.0                 2.5
# 3                       0.0            0.0                 0.7
# 4                       0.1            0.0                 3.9
#
#    transfer orders without opening a bank account amount
# 0                                                4.9
# 1                                                4.1
# 2                                                5.3
# 3                                                3.1
# 4                                                4.2

# %%
target = pd.read_csv("../../sber_dolya_beznala.csv", sep=';')

# %%
target["date"] = pd.to_datetime(target["date"])
target["year"] = target["date"].dt.year
target = target.sort_values(by='date')
target = target[target["date"].dt.month == 1]
target = target.drop(labels=["date"], axis=1)
target = target.drop_duplicates(subset=["region", "year"])
target
# Out:
#                      region  value  year
# 8240   Республика Татарстан   35.6  2017
# 8173  Нижегородская область   38.0  2017
# 8174     Мурманская область   50.1  2017
# 8175                 Москва   44.8  2017
# 8176    Магаданская область   40.3  2017
# ...                     ...    ...   ...
# 189   Архангельская область   76.7  2025
# 188    Астраханская область   64.9  2025
# 187    Белгородская область   69.2  2025
# 186        Брянская область   64.2  2025
# 190        Амурская область   72.8  2025
#
# [751 rows x 3 columns]

# %%
sp11 = pd.read_csv("sp11.csv")
sp11.region = sp11.region.replace({
    "г.Санкт-Петербург": "Санкт-Петербург",
    "г.Москва": "Москва",
    "Кемеровская область – Кузбасс": "Кемеровская область",
    "Республика Северная Осетия – Алания": "Республика Северная Осетия — Алания",
    "Ханты-Мансийский автономный округ – Югра": "Ханты-Мансийский автономный округ — Югра"
})

final_df = pd.merge(sp11, target, on=["region", "year"], how="inner")
final_df
# Out:
#      year           region  population  employable_population  \
# 0    2017   Алтайский край      2303.6                  609.6
# 1    2018   Алтайский край      2277.7                  615.9
# 2    2019   Алтайский край      2250.1                  619.9
# 3    2020   Алтайский край      2224.1                  590.8
# 4    2021   Алтайский край      2193.0                  587.3
# ..    ...              ...         ...                    ...
# 552  2019  Санкт-Петербург      5546.4                 1485.1
# 553  2020  Санкт-Петербург      5580.8                 1444.8
# 554  2021  Санкт-Петербург      5588.5                 1463.9
# 555  2022  Санкт-Петербург      5607.9                 1403.5
# 556  2023  Санкт-Петербург      5600.0                 1430.7
#
#      employable_population_share  value
# 0                           26.5   37.4
# 1                           27.0   45.9
# 2                           27.5   50.0
# 3                           26.6   54.1
# 4                           26.8   58.0
# ..                           ...    ...
# 552                         26.8   56.3
# 553                         25.9   59.2
# 554                         26.2   66.0
# 555                         25.0   68.2
# 556                         25.5   68.0
#
# [557 rows x 6 columns]
