# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

plt.style.use('ggplot')

df_final = pd.DataFrame()

# %% [markdown]
# # T1 Institutional data

# %%
t1 = pd.read_csv("../data/institutional_data/nps_institutional_data.csv")
t1['date'] = pd.to_datetime(t1['date'], format="%d.%m.%Y")
t1.region = t1.region.replace(
    {"Республика Крым**": "Республика Крым",
     "г. Севастополь**": "г. Севастополь",
     "Кемеровская область-Кузбасс": "Кемеровская область",
     "Кемеровская область - Кузбасс": "Кемеровская область",
     "Чукотский авт. округ": "Чукотский автономный округ",
     "Еврейская авт. область": "Еврейская автономная область",
     "Республика Северная Осетия - Алания": "Республика Северная Осетия-Алания"
    }
)
t1["Total number of banking system institutions"] = t1["Total number of banking system institutions"].str.replace(" ", "").astype(float)
t1["additional offices"] = t1["additional offices"].str.replace(" ", "").astype(float)
t1["Number of bank institutions per 1 million inhabitants"] = t1["Number of bank institutions per 1 million inhabitants"].str.replace("-", "0")
t1["Number of bank institutions per 1 million inhabitants"] = t1["Number of bank institutions per 1 million inhabitants"].str.replace(" ", "").astype(float)
t1["Number of bank institutions per 1 million inhabitants"] = t1["Number of bank institutions per 1 million inhabitants"].replace({0: t1["Number of bank institutions per 1 million inhabitants"].mean()})
t1.head()

# %% [markdown]
# # T2 Accounts data

# %%
t2 = pd.read_csv("../data/accounts_data/accounts_data.csv")
t2['date'] = pd.to_datetime(t2['date'], format="%d.%m.%Y")
t2.region = t2.region.replace(
    {"Республика Крым**": "Республика Крым",
     "г. Севастополь**": "г. Севастополь",
     "Кемеровская область-Кузбасс": "Кемеровская область",
     "Кемеровская область - Кузбасс": "Кемеровская область",
     "Еврейская авт. область": "Еврейская автономная область",
     "Республика Северная Осетия - Алания": "Республика Северная Осетия-Алания"
    }
)
t2["total_accounts"] = t2["total_accounts"].str.replace(" ", "").str.replace(",", ".").astype(float)
t2["total_in_credit_org"] = t2["total_in_credit_org"].str.replace(" ", "").str.replace(",", ".").astype(float)
t2["clients-legal entities that are not credit institutions"] = t2["clients-legal entities that are not credit institutions"].str.replace(" ", "").str.replace(",", ".").astype(float)
t2["individual clients"] = t2["individual clients"].str.replace(" ", "").str.replace(",", ".").astype(float)
t2["The number of accounts opened by institutions of the banking system, per 1 resident, units."] = t2["The number of accounts opened by institutions of the banking system, per 1 resident, units."].str.replace(" ", "").str.replace(",", ".").str.replace("-", "0").astype(float)
t2["The number of accounts opened by institutions of the banking system, per 1 resident, units."] = t2["The number of accounts opened by institutions of the banking system, per 1 resident, units."].replace({0: t2["The number of accounts opened by institutions of the banking system, per 1 resident, units."].mean()})
t2.head()
# Out:
#         date                 region  total_accounts  total_in_credit_org  \
# 0 2010-01-01         Алтайский край          5937.4               5935.4
# 1 2010-01-01       Амурская область          2774.8               2774.2
# 2 2010-01-01  Архангельская область          3864.2               3863.4
# 3 2010-01-01   Астраханская область          2688.1               2687.6
# 4 2010-01-01   Белгородская область          4444.1               4443.4
#
#    clients-legal entities that are not credit institutions  \
# 0                                               63.7
# 1                                               29.7
# 2                                               45.1
# 3                                               32.3
# 4                                               50.0
#
#    individual clients  \
# 0              5871.7
# 1              2744.5
# 2              3818.3
# 3              2655.3
# 4              4393.4
#
# ...

# %%
list(set(t1.region.unique()) - set(t2.region.unique()))
# Out:
# ['Читинская область']

# %%
df_final = pd.merge(
    t1, t2,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(df_final.shape)
# Out:
# (4427, 13)

# %% [markdown]
# # T9 Remote accounts (amount)

# %%
t9 = pd.read_csv("../data/remote_accounts_amount/number_remote_accounts.csv")
t9['date'] = pd.to_datetime(t9['date'], format="%d.%m.%Y")
t9.region = t9.region.replace(
    {"Республика Крым**": "Республика Крым",
     "г. Севастополь**": "г. Севастополь",
     "Кемеровская область-Кузбасс": "Кемеровская область",
     "Кемеровская область - Кузбасс": "Кемеровская область",
     "Еврейская авт. область": "Еврейская автономная область",
     "Республика Северная Осетия - Алания": "Республика Северная Осетия-Алания"
    }
)

t9 = t9[["date", "region", "number_of_new_remote_accounts", "number_of_new_remote_accounts_individuals", "number_of_new_remote_accounts_individuals_with_internet", "number_of_new_remote_accounts_individuals_with_sms"]]



t9["number_of_new_remote_accounts"] = t9["number_of_new_remote_accounts"].str.replace(" ", "").str.replace(",", ".").astype(float)
t9["number_of_new_remote_accounts_individuals"] = t9["number_of_new_remote_accounts_individuals"].str.replace(" ", "").str.replace(",", ".").astype(float)
t9["number_of_new_remote_accounts_individuals_with_internet"] = t9["number_of_new_remote_accounts_individuals_with_internet"].str.replace(" ", "").str.replace(",", ".").astype(float)
t9["number_of_new_remote_accounts_individuals_with_sms"] = t9["number_of_new_remote_accounts_individuals_with_sms"].str.replace(" ", "").str.replace(",", ".").astype(float)
t9.head()
# Out:
#         date                 region  number_of_new_remote_accounts  \
# 0 2010-10-01         Алтайский край                          508.2
# 1 2010-10-01       Амурская область                          280.8
# 2 2010-10-01  Архангельская область                          291.7
# 3 2010-10-01   Астраханская область                          668.0
# 4 2010-10-01   Белгородская область                          732.7
#
#    number_of_new_remote_accounts_individuals  \
# 0                                      487.4
# 1                                      275.6
# 2                                      281.0
# 3                                      662.8
# 4                                      721.2
#
#    number_of_new_remote_accounts_individuals_with_internet  \
# 0                                               49.8
# 1                                               29.7
# 2                                               25.5
# 3                                                2.9
# ...

# %%
df_final = pd.merge(
    df_final, t9,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(df_final.shape)
# Out:
# (4427, 17)

# %% [markdown]
# # T10 Bills amount

# %%
from os import listdir
from os.path import isfile, join

mypath = "../data/bills_amount/"

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

sheets = ["Q1", "Q2", "Q3", "Q4"]

cols = [
    "date", "region",
    "orders in electronic form total", "orders in electronic form with internet",
    "payments orders", "payments orders with internet",
    "letter of credit", "payment requirements", "payment requirements with internet",
    "collection orders", "bank orders"
]

t10 = pd.DataFrame(columns=cols)

for file in onlyfiles:
    for sheet in pd.ExcelFile(mypath + file).sheet_names:
        dfs = pd.read_excel(mypath + file, sheet_name=sheet)
        dfs.columns = cols
        for col in dfs.drop(labels=["date", "region"], axis=1).columns:
            try:
                dfs[col] = dfs[col].str.replace(" ", "").str.replace(",", ".").astype(float)
            except Exception as err:
                pass
        t10 = pd.concat([t10, dfs], axis=0)

t10['date'] = pd.to_datetime(t10['date'], format="%d.%m.%Y")
t10.region = t10.region.replace(
    {
         "Республика Крым**": "Республика Крым",
         "г. Севастополь**": "г. Севастополь",
         "Кемеровская область-Кузбасс": "Кемеровская область",
         "Кемеровская область - Кузбасс": "Кемеровская область",
         "Еврейская авт. область": "Еврейская автономная область",
         "Москва и Московская область": "г. Москва и Московская область",
         "Санкт-Петербург": "г. Санкт-Петербург",
         "Республика Северная Осетия - Алания": "Республика Северная Осетия-Алания"
    }
)
t10  = t10.sort_values(by="date")

t10.head()
# Out:
# /var/folders/50/qly_r7y17754hf5lyq92cnjh0000gn/T/ipykernel_11597/3763032404.py:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   t10 = pd.concat([t10, dfs], axis=0)
#          date                             region  \
# 76 2013-01-01     Чувашская Республика - Чувашия
# 55 2013-01-01                    Республика Тыва
# 54 2013-01-01   Республика Татарстан (Татарстан)
# 53 2013-01-01  Республика Северная Осетия-Алания
# 52 2013-01-01           Республика Саха (Якутия)
#
#     orders in electronic form total  orders in electronic form with internet  \
# 76                           1518.5                                    535.3
# 55                             29.5                                      8.1
# ...

# %%
df_final = pd.merge(
    df_final, t10,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(df_final.shape)
# Out:
# (3480, 26)

# %% [markdown]
# # T11 Bills Volume

# %%
from os import listdir
from os.path import isfile, join

mypath = "../data/bills_volume/"

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

sheets = ["Q1", "Q2", "Q3", "Q4"]

cols = [
    "date", "region",
    "volume orders in electronic form total", "volume orders in electronic form with internet",
    "volume payments orders", "volume payments orders with internet",
    "volume letter of credit", "volume payment requirements", "volume payment requirements with internet",
    "volume collection orders", "volume bank orders"
]

t11 = pd.DataFrame(columns=cols)

for file in onlyfiles:
    for sheet in pd.ExcelFile(mypath + file).sheet_names:
        dfs = pd.read_excel(mypath + file, sheet_name=sheet)
        dfs.columns = cols
        for col in dfs.drop(labels=["date", "region"], axis=1).columns:
            try:
                dfs[col] = dfs[col].str.replace(" ", "").str.replace(",", ".").astype(float)
            except Exception as err:
                pass
        t11 = pd.concat([t11, dfs], axis=0)

t11['date'] = pd.to_datetime(t11['date'], format="%d.%m.%Y")
t11.region = t11.region.replace(
    {
        "Республика Крым**": "Республика Крым",
         "г. Севастополь**": "г. Севастополь",
         "Кемеровская область-Кузбасс": "Кемеровская область",
         "Кемеровская область - Кузбасс": "Кемеровская область",
         "Еврейская авт. область": "Еврейская автономная область",
         "Москва и Московская область": "г. Москва и Московская область",
         "Санкт-Петербург": "г. Санкт-Петербург",
         "Республика Северная Осетия - Алания": "Республика Северная Осетия-Алания"
    }
)
# Out:
# /var/folders/50/qly_r7y17754hf5lyq92cnjh0000gn/T/ipykernel_11597/2663155967.py:29: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   t11 = pd.concat([t11, dfs], axis=0)

# %%
df_final = pd.merge(
    df_final, t11,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(df_final.shape)
# list(set(t11.region.unique()) - set(df_final.region.unique()))
# Out:
# (3477, 35)

# %% [markdown]
# # T7 Объем платежей, проведенных через кредитные организации (по платежным инструментам) в территориальном разрезе

# %%
from os import listdir
from os.path import isfile, join

mypath = "../data/t7/"

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

sheets = ["Q1", "Q2", "Q3", "Q4"]



cols = [
    "date", "region",
    "orders amount", "payment orders amount",
    "payment requirements, collection orders amount", "letters of credit amount",
    "checks amount", "bank orders amount", "transfer orders without opening a bank account amount"
]

t7 = pd.DataFrame(columns=cols)

for file in onlyfiles:
    for sheet in pd.ExcelFile(mypath + file).sheet_names:
        dfs = pd.read_excel(mypath + file, sheet_name=sheet)
        dfs.columns = cols
        for col in dfs.drop(labels=["date", "region"], axis=1).columns:
            try:
                dfs[col] = dfs[col].str.replace(" ", "").str.replace(",", ".").astype(float)
            except Exception as err:
                print(col, err)
        t7 = pd.concat([t7, dfs], axis=0)

t7['date'] = pd.to_datetime(t7['date'], format="%d.%m.%Y")
t7.region = t7.region.replace(
    {
        "Республика Крым**": "Республика Крым",
         "г. Севастополь**": "г. Севастополь",
         "Кемеровская область-Кузбасс": "Кемеровская область",
         "Кемеровская область - Кузбасс": "Кемеровская область",
         "Еврейская авт. область": "Еврейская автономная область",
         "Москва и Московская область": "г. Москва и Московская область",
         "Санкт-Петербург": "г. Санкт-Петербург",
         "Республика Северная Осетия - Алания": "Республика Северная Осетия-Алания"
    }
)
# Out:
# /var/folders/50/qly_r7y17754hf5lyq92cnjh0000gn/T/ipykernel_11597/3569751105.py:30: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   t7 = pd.concat([t7, dfs], axis=0)

# %%
df_final = pd.merge(
    df_final, t7,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(df_final.shape)
# list(set(t11.region.unique()) - set(df_final.region.unique()))
# Out:
# (3435, 42)

# %%
df_final.to_csv("../data/final_mart_30_04_8_35.csv", index=False)

# %% [markdown]
# # Index Construction

# %%
from scipy.stats import gmean

# %%
df = df_final.copy()

df = df[~df["region"].isin(["Херсонская область", "Запорожская область", "Луганская Народная Республика", "Донецкая Народная Республика", "г. Севастополь", "Республика Крым"])]

corr_features = [
    "total_accounts",
    "additional offices",
    "volume bank orders",
    "volume payments orders",
    "volume orders in electronic form total",
    "letter of credit",
    "volume letter of credit",
    "volume payment requirements with internet",
    "volume payments orders with internet",
    "individual clients",
    #"individual clients",
    # "additional offices",
    "total_in_credit_org",
    "number_of_new_remote_accounts_individuals_with_sms",
    "clients-legal entities that are not credit institutions",
    "number_of_new_remote_accounts",
    "number_of_new_remote_accounts_individuals_with_internet",
    "orders in electronic form total",
    "number_of_new_remote_accounts_individuals",
    "orders in electronic form with internet",
    "payments orders",
    "payment requirements",
    # "bank orders",
    "branches of credit organizations",
    "letters of credit amount",
    "bank orders amount",
    "transfer orders without opening a bank account amount",
    "payment orders amount",
    "orders amount",
    "volume collection orders",
    "collection orders",
    "payments orders with internet",
    "volume payment requirements",
    "payment requirements, collection orders amount",
    "checks amount"
    # "clients-legal entities that are not credit institutions",
    # "number_of_new_remote_accounts_individuals",
    # "clients-legal entities that are not credit institutions",
    # "number_of_new_remote_accounts",
    # "clients-legal entities that are not credit institutions",
    # "number_of_new_remote_accounts_individuals",
    # "number_of_new_remote_accounts_individuals",
    # "total_in_credit_org",
    # "number_of_new_remote_accounts_individuals_with_internet"
]

df = df.drop(labels=corr_features, axis=1, errors="ignore")

# %%
df.select_dtypes("float").corr("spearman")

import seaborn as sns
# %matplotlib inline

# load the Auto dataset

# calculate the correlation matrix on the numeric columns
corr = df.select_dtypes("float").rename(columns={
    "bank orders": "volume bank orders",
    "The number of accounts opened by institutions of the banking system, per 1 resident, units.": "accounts per 1",
    "Number of bank institutions per 1 million inhabitants": "bank_isnt_per_1",
    "Total number of banking system institutions": "total_bank",
    "volume orders in electronic form with internet": "vol_internet",
    "payment requirements with internet": "pay_internet"
}).corr("spearman")#auto_df.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr, annot=True, linewidths=.5,)
# Out:
# <Axes: >

# %%
pd.set_option("display.max_columns", None)
df.select_dtypes("float").describe().round(2)
# Out:
#        Total number of banking system institutions  \
# count                                      3349.00
# mean                                        432.85
# std                                         639.38
# min                                          11.00
# 25%                                         154.00
# 50%                                         267.00
# 75%                                         498.00
# max                                        7403.00
#
#        Number of bank institutions per 1 million inhabitants  \
# count                                            3349.00
# mean                                              235.45
# std                                                85.07
# min                                                23.00
# 25%                                               186.00
# 50%                                               230.00
# 75%                                               287.00
# ...

# %%
df.columns
# Out:
# Index(['date', 'region', 'Total number of banking system institutions',
#        'institutions of the Bank of Russia', 'credit institutions',
#        'Number of bank institutions per 1 million inhabitants',
#        'The number of accounts opened by institutions of the banking system, per 1 resident, units.',
#        'payment requirements with internet', 'bank orders',
#        'volume orders in electronic form with internet'],
#       dtype='object')

# %%
# for col in df.drop(labels=["region", "date"], axis=1).columns:
#     df[f'{col}_normalized'] = (
#         df.groupby(['date'])[col]
#         .transform(lambda x: (x - x.min()) / (x.max() - x.min()))
#     )

import numpy as np

for col in df.drop(labels=["region", "date"], axis=1).columns:
    df[f'{col}_normalized'] = (
        df.groupby(['date'])[col]
        .transform(
            lambda x: (lambda tx: (tx - tx.min()) / (tx.max() - tx.min() + 1e-8))(  # +1e-8 чтобы избежать деления на 0
                np.where(x >= 1, np.log(x), 0)  # Если x < 1 → 0, иначе log(x)
            )
        )
    )
# Out:
# /Users/ppp/env/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/ppp/env/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/ppp/env/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/ppp/env/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/ppp/env/lib/python3.13/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
def geometric_mean_no_zeros(row):
    # Отбираем только значения больше нуля
    positive_values = row[row > 0]
    if len(positive_values) == 0:  # Если все значения равны нулю
        return 0
    return gmean(positive_values)

df['geometric_mean'] = df[df.columns[df.columns.str.contains("_normalized")]].apply(geometric_mean_no_zeros, axis=1)

# %%
df = df.sort_values(by=["date", "region"])
df.index = df.date

# %%
pd.set_option("display.max_rows", 100)

# %%
df[(df["date"].dt.year == 2023) & (df["date"].dt.month == 10)].sort_values(by="geometric_mean", ascending=False)[["region", "geometric_mean"]]
# Out:
#                                        region  geometric_mean
# date
# 2023-10-01     г. Москва и Московская область        0.934804
# 2023-10-01                 г. Санкт-Петербург        0.672488
# 2023-10-01                Воронежская область        0.633551
# 2023-10-01              Новосибирская область        0.617470
# 2023-10-01               Свердловская область        0.608611
# 2023-10-01   Республика Татарстан (Татарстан)        0.595859
# 2023-10-01            Республика Башкортостан        0.595174
# 2023-10-01                  Тюменская область        0.580736
# 2023-10-01                 Краснодарский край        0.578221
# 2023-10-01                   Хабаровский край        0.561758
# 2023-10-01                Челябинская область        0.543648
# 2023-10-01                    Приморский край        0.543035
# 2023-10-01                 Ростовская область        0.540221
# 2023-10-01               Белгородская область        0.540077
# ...

# %%
import matplotlib.pyplot as plt

df = df.rename(
    columns={
        "bank orders_normalized": "volume bank orders",
    "The number of accounts opened by institutions of the banking system, per 1 resident, units._normalized": "accounts per 1",
    "Number of bank institutions per 1 million inhabitants_normalized": "bank_isnt_per_1",
    "Total number of banking system institutions_normalized": "total_bank",
    "volume orders in electronic form with internet_normalized": "vol_internet",
    "payment requirements with internet_normalized": "pay_internet"
    }
)

factors = ["volume bank orders", "accounts per 1", "bank_isnt_per_1", "total_bank", "vol_internet", "pay_internet"]
df_min = df[(df["date"].dt.year == 2023) & (df["date"].dt.month == 10)].sort_values(by="geometric_mean", ascending=False)
df_mosc = df[df["region"] == "Камчатский край"][factors]
df_st = df[df["region"] == "Саратовская область"][factors]

N = len(factors)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles += angles[:1]  # Замыкаем круг



values =df_mosc.mean().values.tolist()
values += values[:1]

values_st =df_st.mean().values.tolist()
values_st += values_st[:1]

# Инициализируем график
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'polar': True})

# Рисуем линию
ax.plot(angles, values, color='blue', linewidth=2, label='Kamchatka Krai')
ax.plot(angles, values_st, color='green', linewidth=2, label='Saratov Oblast')



# Настраиваем оси
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_rlabel_position(0)

# Добавляем подписи
plt.legend(loc='best')
plt.xticks(angles[:-1], factors)
plt.title('Middle-class Regions', y=1.08)
plt.ylim(0, 1 * 1.1)
# Out:
# (0.0, 1.1)

# %%
import matplotlib.pyplot as plt

df = df.rename(
    columns={
        "bank orders_normalized": "volume bank orders",
    "The number of accounts opened by institutions of the banking system, per 1 resident, units._normalized": "accounts per 1",
    "Number of bank institutions per 1 million inhabitants_normalized": "bank_isnt_per_1",
    "Total number of banking system institutions_normalized": "total_bank",
    "volume orders in electronic form with internet_normalized": "vol_internet",
    "payment requirements with internet_normalized": "pay_internet"
    }
)

factors = ["volume bank orders", "accounts per 1", "bank_isnt_per_1", "total_bank", "vol_internet", "pay_internet"]
df_min = df[(df["date"].dt.year == 2023) & (df["date"].dt.month == 10)].sort_values(by="geometric_mean", ascending=False)
df_mosc = df[df["region"] == "г. Москва и Московская область"][factors]
df_st = df[df["region"] == "г. Санкт-Петербург"][factors]

N = len(factors)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles += angles[:1]  # Замыкаем круг



values =df_mosc.mean().values.tolist()
values += values[:1]

values_st =df_st.mean().values.tolist()
values_st += values_st[:1]

# Инициализируем график
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'polar': True})

# Рисуем линию
ax.plot(angles, values, color='blue', linewidth=2, label='Moscow')
ax.plot(angles, values_st, color='green', linewidth=2, label='St. Petersburg')

# Настраиваем оси
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_rlabel_position(0)

# Добавляем подписи
plt.legend(loc='best')
plt.xticks(angles[:-1], factors)
plt.title('Top Regions', y=1.08)
plt.ylim(0, 1 * 1.1)
# Out:
# (0.0, 1.1)

# %%
import matplotlib.pyplot as plt

df = df.rename(
    columns={
        "bank orders_normalized": "volume bank orders",
    "The number of accounts opened by institutions of the banking system, per 1 resident, units._normalized": "accounts per 1",
    "Number of bank institutions per 1 million inhabitants_normalized": "bank_isnt_per_1",
    "Total number of banking system institutions_normalized": "total_bank",
    "volume orders in electronic form with internet_normalized": "vol_internet",
    "payment requirements with internet_normalized": "pay_internet"
    }
)

factors = ["volume bank orders", "accounts per 1", "bank_isnt_per_1", "total_bank", "vol_internet", "pay_internet"]
df_min = df[(df["date"].dt.year == 2023) & (df["date"].dt.month == 10)].sort_values(by="geometric_mean", ascending=False)
df_mosc = df[df["region"] == "Чеченская Республика"][factors]
df_st = df[df["region"] == "Республика Дагестан"][factors]

N = len(factors)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles += angles[:1]  # Замыкаем круг



values =df_mosc.mean().values.tolist()
values += values[:1]

values_st =df_st.mean().values.tolist()
values_st += values_st[:1]

# Инициализируем график
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw={'polar': True})

# Рисуем линию
ax.plot(angles, values, color='blue', linewidth=2, label='Chechen')
ax.plot(angles, values_st, color='green', linewidth=2, label='Republic of Dagestan')

# Настраиваем оси
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_rlabel_position(0)

# Добавляем подписи
plt.legend(loc='best')
plt.xticks(angles[:-1], factors)
plt.title('Losers Regions', y=1.08)
plt.ylim(0, 1 * 1.1)
# Out:
# (0.0, 1.1)

# %%
df[df["region"].isin(["г. Москва и Московская область"])]["geometric_mean"].plot()
df[df["region"].isin(["г. Санкт-Петербург"])]["geometric_mean"].plot()
df[df["region"].isin(["Самарская область"])]["geometric_mean"].plot()
df[df["region"].isin(["Республика Ингушетия"])]["geometric_mean"].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df
# Out:
#                  date                          region  \
# date
# 2013-01-01 2013-01-01            Астраханская область
# 2013-01-01 2013-01-01            Белгородская область
# 2013-01-01 2013-01-01                Брянская область
# 2013-01-01 2013-01-01            Владимирская область
# 2013-01-01 2013-01-01           Волгоградская область
# ...               ...                             ...
# 2023-10-01 2023-10-01  Чувашская Республика - Чувашия
# 2023-10-01 2023-10-01      Чукотский автономный округ
# 2023-10-01 2023-10-01             Ярославская область
# 2023-10-01 2023-10-01  г. Москва и Московская область
# 2023-10-01 2023-10-01              г. Санкт-Петербург
#
#             Total number of banking system institutions  \
# date
# 2013-01-01                                        296.0
# 2013-01-01                                        532.0
# 2013-01-01                                        334.0
# 2013-01-01                                        482.0
# ...

# %%
df.reset_index(drop=True)[["date", "geometric_mean"]].groupby("date").median().rename(columns={"geometric_mean": "NPSD Index"}).plot()
plt.legend(loc="best")
plt.show()

# %%
rename_dict = {
    'Астраханская область': 'Astrakhan region',
    'Белгородская область': 'Belgorod region',
    'Брянская область': 'Bryansk region',
    'Владимирская область': 'Vladimir region',
    'Волгоградская область': 'Volgograd region',
    'Вологодская область': 'Vologda Region',
    'Воронежская область': 'Voronezh region',
    'Еврейская автономная область': 'Jewish Autonomous Region',
    'Забайкальский край': 'Zabaykalsky Krai',
    'Ивановская область': 'Ivanovo region',
    'Иркутская область': 'Irkutsk region',
    'Кабардино-Балкарская Республика': 'Kabardino-Balkar Republic',
    'Калининградская область': 'Kaliningrad region',
    'Калужская область': 'Kaluga region',
    'Камчатский край': 'Kamchatka Krai',
    'Карачаево-Черкесская Республика': 'Karachay-Cherkess Republic',
    'Кемеровская область': 'Kemerovo region',
    'Кировская область': 'Kirov region',
    'Костромская область': 'Kostroma region',
    'Краснодарский край': 'Krasnodar region',
    'Красноярский край': 'Krasnoyarsk region',
    'Курганская область': 'Kurgan region',
    'Курская область': 'Kursk region',
    'Ленинградская область': 'Leningrad region',
    'Липецкая область': 'Lipetsk region',
    'Магаданская область': 'Magadan Region',
    'Мурманская область': 'Murmansk region',
    'Нижегородская область': 'Nizhny Novgorod Region',
    'Новгородская область': 'Novgorod region',
    'Новосибирская область': 'Novosibirsk region',
    'Омская область': 'Omsk region',
    'Оренбургская область': 'Orenburg region',
    'Орловская область': 'Oryol Region',
    'Пензенская область': 'Penza region',
    'Пермский край': 'Perm',
    'Приморский край': 'Primorsky Krai',
    'Псковская область': 'Pskov region',
    'Республика Адыгея (Адыгея)': 'Republic of Adygea',
    'Республика Алтай': 'Altai Republic',
    'Республика Башкортостан': 'Republic of Bashkortostan',
    'Республика Бурятия': 'The Republic of Buryatia',
    'Республика Дагестан': 'The Republic of Dagestan',
    'Республика Ингушетия': 'The Republic of Ingushetia',
    'Республика Калмыкия': 'Republic of Kalmykia',
    'Республика Карелия': 'The Republic of Karelia',
    'Республика Коми': 'Komi Republic',
    'Республика Марий Эл': 'Mari El Republic',
    'Республика Мордовия': 'The Republic of Mordovia',
    'Республика Саха (Якутия)': 'The Republic of Sakha (Yakutia)',
    'Республика Татарстан (Татарстан)': 'Republic of Tatarstan',
    'Республика Тыва': 'Tyva Republic',
    'Республика Хакасия': 'The Republic of Khakassia',
    'Ростовская область': 'Rostov region',
    'Рязанская область': 'Ryazan Oblast',
    'Самарская область': 'Samara Region',
    'Саратовская область': 'Saratov region',
    'Сахалинская область': 'Sakhalin region',
    'Свердловская область': 'Sverdlovsk region',
    'Смоленская область': 'Smolensk region',
    'Ставропольский край': 'Stavropol region',
    'Тамбовская область': 'Tambov Region',
    'Тверская область': 'Tver region',
    'Томская область': 'Tomsk region',
    'Тульская область': 'Tula region',
    'Тюменская область': 'Tyumen region',
    'Удмуртская Республика': 'Udmurt republic',
    'Ульяновская область': 'Ulyanovsk region',
    'Хабаровский край': 'Khabarovsk region',
    'Челябинская область': 'Chelyabinsk region',
    'Чеченская Республика': 'Chechen Republic',
    'Чувашская Республика - Чувашия': 'Chuvash Republic',
    'Чукотский автономный округ': 'Chukotka Autonomous Okrug',
    'Ярославская область': 'Yaroslavl region',
    'Амурская область': 'Amurskaya Oblast',
    'Архангельская область': 'Arkhangelsk region',
    'Алтайский край': 'Altai region',
    'Республика Северная Осетия-Алания': 'Republic of North Ossetia - Alania',
    'г. Москва и Московская область': 'Moscow and Moscow region',
    'г. Санкт-Петербург': 'St. Petersburg'
}

# %%
df_en = df.copy()
df_en["region"] = df_en["region"].replace(rename_dict)

# %%
df_en.to_csv("payment_index.csv", index=False)

# %%
df_en.region.unique()
# Out:
# array(['Astrakhan region', 'Belgorod region', 'Bryansk region',
#        'Vladimir region', 'Volgograd region', 'Vologda Region',
#        'Voronezh region', 'Jewish Autonomous Region', 'Zabaykalsky Krai',
#        'Ivanovo region', 'Irkutsk region', 'Kabardino-Balkar Republic',
#        'Kaliningrad region', 'Kaluga region', 'Kamchatka Krai',
#        'Karachay-Cherkess Republic', 'Kemerovo region', 'Kirov region',
#        'Kostroma region', 'Krasnodar region', 'Krasnoyarsk region',
#        'Kurgan region', 'Kursk region', 'Leningrad region',
#        'Lipetsk region', 'Magadan Region', 'Murmansk region',
#        'Nizhny Novgorod Region', 'Novgorod region', 'Novosibirsk region',
#        'Omsk region', 'Orenburg region', 'Oryol Region', 'Penza region',
#        'Perm', 'Primorsky Krai', 'Pskov region', 'Republic of Adygea',
#        'Altai Republic', 'Republic of Bashkortostan',
#        'The Republic of Buryatia', 'The Republic of Dagestan',
# ...
