# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Institutional data

# %%
inst_data = pd.read_csv("../data/institutional_data/nps_institutional_data.csv")
inst_data['date'] = pd.to_datetime(inst_data['date'], format="%d.%m.%Y")
inst_data.region = inst_data.region.replace(
    {"Республика Крым**": "Республика Крым",
     "г. Севастополь**": "г. Севастополь",
     "Кемеровская область-Кузбасс": "Кемеровская область",
     "Кемеровская область - Кузбасс": "Кемеровская область",
     "Чукотский авт. округ": "Чукотский автономный округ",
     "Еврейская авт. область": "Еврейская автономная область",
    }
)
inst_data["Total number of banking system institutions"] = inst_data["Total number of banking system institutions"].str.replace(" ", "").astype(float)
inst_data["additional offices"] = inst_data["additional offices"].str.replace(" ", "").astype(float)
inst_data["Number of bank institutions per 1 million inhabitants"] = inst_data["Number of bank institutions per 1 million inhabitants"].str.replace("-", "0")
inst_data["Number of bank institutions per 1 million inhabitants"] = inst_data["Number of bank institutions per 1 million inhabitants"].str.replace(" ", "").astype(float)
inst_data["Number of bank institutions per 1 million inhabitants"] = inst_data["Number of bank institutions per 1 million inhabitants"].replace({0: inst_data["Number of bank institutions per 1 million inhabitants"].mean()})
inst_data.head()
# Out:
#         date                 region  \
# 0 2008-10-01         Алтайский край
# 1 2008-10-01       Амурская область
# 2 2008-10-01  Архангельская область
# 3 2008-10-01   Астраханская область
# 4 2008-10-01   Белгородская область
#
#    Total number of banking system institutions  \
# 0                                       1005.0
# 1                                        251.0
# 2                                        310.0
# 3                                        273.0
# 4                                        465.0
#
#    institutions of the Bank of Russia  credit institutions  \
# 0                                  16                    8
# 1                                   4                    5
# 2                                  15                    3
# 3                                   4                    5
# 4                                   5                    6
#
#    branches of credit organizations  additional offices  \
# 0                                59               300.0
# 1                                17               173.0
# 2                                35               142.0
# 3                                30               112.0
# 4                                33               135.0
#
#    Number of bank institutions per 1 million inhabitants
# 0                                              398.0
# 1                                              287.0
# 2                                              242.0
# 3                                              275.0
# 4                                              307.0

# %% [markdown]
# # Accounts data

# %%
accounts_data = pd.read_csv("../data/accounts_data/accounts_data.csv")
accounts_data['date'] = pd.to_datetime(accounts_data['date'], format="%d.%m.%Y")
accounts_data.region = accounts_data.region.replace(
    {"Республика Крым**": "Республика Крым",
     "г. Севастополь**": "г. Севастополь",
     "Кемеровская область-Кузбасс": "Кемеровская область",
     "Кемеровская область - Кузбасс": "Кемеровская область",
     "Еврейская авт. область": "Еврейская автономная область",
    }
)
accounts_data["total_accounts"] = accounts_data["total_accounts"].str.replace(" ", "").str.replace(",", ".").astype(float)
accounts_data["total_in_credit_org"] = accounts_data["total_in_credit_org"].str.replace(" ", "").str.replace(",", ".").astype(float)
accounts_data["clients-legal entities that are not credit institutions"] = accounts_data["clients-legal entities that are not credit institutions"].str.replace(" ", "").str.replace(",", ".").astype(float)
accounts_data["individual clients"] = accounts_data["individual clients"].str.replace(" ", "").str.replace(",", ".").astype(float)
accounts_data["The number of accounts opened by institutions of the banking system, per 1 resident, units."] = accounts_data["The number of accounts opened by institutions of the banking system, per 1 resident, units."].str.replace(" ", "").str.replace(",", ".").str.replace("-", "0").astype(float)
accounts_data["The number of accounts opened by institutions of the banking system, per 1 resident, units."] = accounts_data["The number of accounts opened by institutions of the banking system, per 1 resident, units."].replace({0: accounts_data["The number of accounts opened by institutions of the banking system, per 1 resident, units."].mean()})
accounts_data.head()
# Out:
#         date                 region  total_accounts  total_in_credit_org  \
# 0 2010-01-01         Алтайский край          5937.4               5935.4
# 1 2010-01-01       Амурская область          2774.8               2774.2
# 2 2010-01-01  Архангельская область          3864.2               3863.4
# 3 2010-01-01   Астраханская область          2688.1               2687.6
# 4 2010-01-01   Белгородская область          4444.1               4443.4
#
#    clients-legal entities that are not credit institutions  \
# 0                                               63.7
# 1                                               29.7
# 2                                               45.1
# 3                                               32.3
# 4                                               50.0
#
#    individual clients  \
# 0              5871.7
# 1              2744.5
# 2              3818.3
# 3              2655.3
# 4              4393.4
#
#    The number of accounts opened by institutions of the banking system, per 1 resident, units.
# 0                                                2.4
# 1                                                3.2
# 2                                                3.1
# 3                                                2.7
# 4                                                2.9

# %%
list(set(inst_data.region.unique()) - set(accounts_data.region.unique()))
# Out:
# ['Читинская область']

# %%
accounts_inst_merged = pd.merge(
    accounts_data, inst_data,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(accounts_inst_merged.shape)
# Out:
# (4427, 13)

# %% [markdown]
# # Remote accounts (amount)

# %%
remote_accounts_amount_data = pd.read_csv("../data/remote_accounts_amount/number_remote_accounts.csv")
remote_accounts_amount_data['date'] = pd.to_datetime(remote_accounts_amount_data['date'], format="%d.%m.%Y")
remote_accounts_amount_data.region = remote_accounts_amount_data.region.replace(
    {"Республика Крым**": "Республика Крым",
     "г. Севастополь**": "г. Севастополь",
     "Кемеровская область-Кузбасс": "Кемеровская область",
     "Кемеровская область - Кузбасс": "Кемеровская область",
     "Еврейская авт. область": "Еврейская автономная область",
    }
)

remote_accounts_amount_data = remote_accounts_amount_data[["date", "region", "number_of_new_remote_accounts", "number_of_new_remote_accounts_individuals", "number_of_new_remote_accounts_individuals_with_internet", "number_of_new_remote_accounts_individuals_with_sms"]]



remote_accounts_amount_data["number_of_new_remote_accounts"] = remote_accounts_amount_data["number_of_new_remote_accounts"].str.replace(" ", "").str.replace(",", ".").astype(float)
remote_accounts_amount_data["number_of_new_remote_accounts_individuals"] = remote_accounts_amount_data["number_of_new_remote_accounts_individuals"].str.replace(" ", "").str.replace(",", ".").astype(float)
remote_accounts_amount_data["number_of_new_remote_accounts_individuals_with_internet"] = remote_accounts_amount_data["number_of_new_remote_accounts_individuals_with_internet"].str.replace(" ", "").str.replace(",", ".").astype(float)
remote_accounts_amount_data["number_of_new_remote_accounts_individuals_with_sms"] = remote_accounts_amount_data["number_of_new_remote_accounts_individuals_with_sms"].str.replace(" ", "").str.replace(",", ".").astype(float)
remote_accounts_amount_data.head()
# Out:
#         date                 region  number_of_new_remote_accounts  \
# 0 2010-10-01         Алтайский край                          508.2
# 1 2010-10-01       Амурская область                          280.8
# 2 2010-10-01  Архангельская область                          291.7
# 3 2010-10-01   Астраханская область                          668.0
# 4 2010-10-01   Белгородская область                          732.7
#
#    number_of_new_remote_accounts_individuals  \
# 0                                      487.4
# 1                                      275.6
# 2                                      281.0
# 3                                      662.8
# 4                                      721.2
#
#    number_of_new_remote_accounts_individuals_with_internet  \
# 0                                               49.8
# 1                                               29.7
# 2                                               25.5
# 3                                                2.9
# 4                                               35.8
#
#    number_of_new_remote_accounts_individuals_with_sms
# 0                                              342.2
# 1                                               38.9
# 2                                              172.2
# 3                                              127.8
# 4                                              127.5

# %%
accounts_inst_remote_accounts_merged = pd.merge(
    accounts_inst_merged, remote_accounts_amount_data,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(accounts_inst_remote_accounts_merged.shape)
# Out:
# (4427, 17)

# %%
accounts_inst_remote_accounts_merged.to_csv("for_index.csv")

# %% [markdown]
# # Bills amount

# %%
from os import listdir
from os.path import isfile, join

mypath = "../data/bills_amount/"

onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

sheets = ["Q1", "Q2", "Q3", "Q4"]

cols = [
    "date", "region",
    "orders in electronic form total", "orders in electronic form with internet",
    "payments orders", "payments orders with internet",
    "letter of credit", "payment requirements", "payment requirements with internet",
    "collection orders", "bank orders"
]

bills = pd.DataFrame(columns=cols)

for file in onlyfiles:
    for sheet in pd.ExcelFile(mypath + file).sheet_names:
        dfs = pd.read_excel(mypath + file, sheet_name=sheet)
        dfs.columns = cols
        bills = pd.concat([bills, dfs], axis=0)

bills['date'] = pd.to_datetime(bills['date'], format="%d.%m.%Y")
bills.region = bills.region.replace(
    {"Республика Крым**": "Республика Крым",
     "г. Севастополь**": "г. Севастополь",
     "Кемеровская область-Кузбасс": "Кемеровская область",
     "Кемеровская область - Кузбасс": "Кемеровская область",
     "Еврейская авт. область": "Еврейская автономная область",
    }
)

for col in bills.drop(labels=["date", "region"], axis=1).columns:
    bills[col] = bills[col].str.replace(" ", "").str.replace(",", ".").astype(float)

# %%
pd.ExcelFile("../data/bills_amount/T10_2023_Full.xlsx").sheet_names
# Out:
# ['1Q 2023', '2Q 2023', '3Q 2023', '4Q 2023']

# %%
bills.sort_values(by="date").tail(99)
# Out:
#          date                             region  \
# 22 2023-07-01                  Кировская область
# 21 2023-07-01                Кемеровская область
# 20 2023-07-01    Карачаево-Черкесская Республика
# 27 2023-07-01                    Курская область
# 75 2023-07-01                  Тюменская область
# 78 2023-07-01                   Хабаровский край
# 77 2023-07-01                Ульяновская область
# 79 2023-07-01                 Херсонская область
# 80 2023-07-01                Челябинская область
# 81 2023-07-01               Чеченская Республика
# 82 2023-07-01     Чувашская Республика - Чувашия
# 83 2023-07-01         Чукотский автономный округ
# 84 2023-07-01                Ярославская область
# 76 2023-07-01              Удмуртская Республика
# 62 2023-10-01                  Рязанская область
# 61 2023-10-01                 Ростовская область
# 60 2023-10-01                 Республика Хакасия
# 59 2023-10-01                    Республика Тыва
# 58 2023-10-01   Республика Татарстан (Татарстан)
# 57 2023-10-01  Республика Северная Осетия-Алания
# 56 2023-10-01           Республика Саха (Якутия)
# 55 2023-10-01                Республика Мордовия
# 51 2023-10-01                 Республика Карелия
# 53 2023-10-01                    Республика Крым
# 52 2023-10-01                    Республика Коми
# 63 2023-10-01                  Самарская область
# 50 2023-10-01                Республика Калмыкия
# 49 2023-10-01               Республика Ингушетия
# 48 2023-10-01                Республика Дагестан
# 47 2023-10-01                 Республика Бурятия
# 61                              NaN                                      NaN
# 60                              NaN                                      NaN
# 59                              NaN                                      NaN
# 58                              NaN                                      NaN
# 57                              NaN                                      NaN
# 56                              NaN                                      NaN
# 55                              NaN                                      NaN
# 51                              NaN                                      NaN
# 53                              NaN                                      NaN
# 52                              NaN                                      NaN
# 63                              NaN                                      NaN
# 50                              NaN                                      NaN
# 49                              NaN                                      NaN
# 48                              NaN                                      NaN
# 47                              NaN                                      NaN
# 46                              NaN                                      NaN
# 54                              NaN                                      NaN
# 64                              NaN                                      NaN
# 67                              NaN                                      NaN
# 66                              NaN                                      NaN
# 84                              NaN                                      NaN
# 83                              NaN                                      NaN
# 82                              NaN                                      NaN
# 81                              NaN                                      NaN
# 80                              NaN                                      NaN
# 79                              NaN                                      NaN
# 78                              NaN                                      NaN
# 77                              NaN                                      NaN
# 65                              NaN                                      NaN
# 76                              NaN                                      NaN
# 74                              NaN                                      NaN
# 73                              NaN                                      NaN
# 72                              NaN                                      NaN
# 71                              NaN                                      NaN
# 70                              NaN                                      NaN
# 69                              NaN                                      NaN
# 68                              NaN                                      NaN
# 45                              NaN                                      NaN
# 75                              NaN                                      NaN
# 44                              NaN                                      NaN
# 40                              NaN                                      NaN
# 42                              NaN                                      NaN
# 18                              NaN                                      NaN
# 17                              NaN                                      NaN
# 16                              NaN                                      NaN
# 15                              NaN                                      NaN
# 14                              NaN                                      NaN
# 13                              NaN                                      NaN
# 12                              NaN                                      NaN
# 11                              NaN                                      NaN
# 19                              NaN                                      NaN
# 10                              NaN                                      NaN
# 8                               NaN                                      NaN
# 7                               NaN                                      NaN
# 6                               NaN                                      NaN
# 5                               NaN                                      NaN
# 3                               NaN                                      NaN
# 2                               NaN                                      NaN
# 1                               NaN                                      NaN
# 0                               NaN                                      NaN
# 9                               NaN                                      NaN
# 43                              NaN                                      NaN
# 20                              NaN                                      NaN
# 22                              NaN                                      NaN
# 41                              NaN                                      NaN
# 39                              NaN                                      NaN
# 38                              NaN                                      NaN
# 37                              NaN                                      NaN
# 36                              NaN                                      NaN
# 35                              NaN                                      NaN
# 34                              NaN                                      NaN
# 33                              NaN                                      NaN
# 21                              NaN                                      NaN
# 32                              NaN                                      NaN
# 30                              NaN                                      NaN
# 29                              NaN                                      NaN
# 28                              NaN                                      NaN
# 27                              NaN                                      NaN
# 26                              NaN                                      NaN
# 25                              NaN                                      NaN
# 24                              NaN                                      NaN
# 23                              NaN                                      NaN
# 31                              NaN                                      NaN
# 4                               NaN                                      NaN
#
#     payments orders  payments orders with internet  letter of credit  \
# 22              NaN                            NaN               NaN
# 21              NaN                            NaN               NaN
# 20              NaN                            NaN               NaN
# 27              NaN                            NaN               NaN
# 75              NaN                            NaN               NaN
# 78              NaN                            NaN               NaN
# 77              NaN                            NaN               NaN
# 79              NaN                            NaN               NaN
# 80              NaN                            NaN               NaN
# 81              NaN                            NaN               NaN
# 82              NaN                            NaN               NaN
# 83              NaN                            NaN               NaN
# 84              NaN                            NaN               NaN
# 76              NaN                            NaN               NaN
# 62              NaN                            NaN               NaN
# 61              NaN                            NaN               NaN
# 60              NaN                            NaN               NaN
# 59              NaN                            NaN               NaN
# 52                NaN          NaN
# 63                NaN          NaN
# 50                NaN          NaN
# 49                NaN          NaN
# 48                NaN          NaN
# 47                NaN          NaN
# 46                NaN          NaN
# 54                NaN          NaN
# 64                NaN          NaN
# 67                NaN          NaN
# 66                NaN          NaN
# 84                NaN          NaN
# 83                NaN          NaN
# 82                NaN          NaN
# 81                NaN          NaN
# 80                NaN          NaN
# 79                NaN          NaN
# 78                NaN          NaN
# 77                NaN          NaN
# 65                NaN          NaN
# 76                NaN          NaN
# 74                NaN          NaN
# 73                NaN          NaN
# 72                NaN          NaN
# 71                NaN          NaN
# 70                NaN          NaN
# 69                NaN          NaN
# 68                NaN          NaN
# 45                NaN          NaN
# 75                NaN          NaN
# 44                NaN          NaN
# 40                NaN          NaN
# 42                NaN          NaN
# 18                NaN          NaN
# 17                NaN          NaN
# 16                NaN          NaN
# 15                NaN          NaN
# 14                NaN          NaN
# 13                NaN          NaN
# 12                NaN          NaN
# 11                NaN          NaN
# 19                NaN          NaN
# 10                NaN          NaN
# 8                 NaN          NaN
# 7                 NaN          NaN
# 6                 NaN          NaN
# 5                 NaN          NaN
# 3                 NaN          NaN
# 2                 NaN          NaN
# 1                 NaN          NaN
# 0                 NaN          NaN
# 9                 NaN          NaN
# 43                NaN          NaN
# 20                NaN          NaN
# 22                NaN          NaN
# 41                NaN          NaN
# 39                NaN          NaN
# 38                NaN          NaN
# 37                NaN          NaN
# 36                NaN          NaN
# 35                NaN          NaN
# 34                NaN          NaN
# 33                NaN          NaN
# 21                NaN          NaN
# 32                NaN          NaN
# 30                NaN          NaN
# 29                NaN          NaN
# 28                NaN          NaN
# 27                NaN          NaN
# 26                NaN          NaN
# 25                NaN          NaN
# 24                NaN          NaN
# 23                NaN          NaN
# 31                NaN          NaN
# 4                 NaN          NaN

# %%
bills_accounts_inst_remote_accounts_merged = pd.merge(
    accounts_inst_remote_accounts_merged, bills,
    on=["date", "region"], how="inner"
).drop_duplicates(
    subset=["date", "region"]
)
print(bills_accounts_inst_remote_accounts_merged.shape)
# Out:
# (3213, 26)

# %%
bills.sort_values(by="date")
# Out:
#          date                               region  \
# 76 2013-01-01       Чувашская Республика - Чувашия
# 55 2013-01-01                      Республика Тыва
# 54 2013-01-01     Республика Татарстан (Татарстан)
# 53 2013-01-01  Республика Северная Осетия - Алания
# 52 2013-01-01             Республика Саха (Якутия)
# ..        ...                                  ...
# 58 2022-10-01     Республика Татарстан (Татарстан)
# 57 2022-10-01    Республика Северная Осетия-Алания
# 56 2022-10-01             Республика Саха (Якутия)
# 69 2022-10-01                   Смоленская область
# 22 2022-10-01                    Кировская область
#
#     orders in electronic form total  orders in electronic form with internet  \
# 76                           1518.5                                    535.3
# 55                             29.5                                      8.1
# 54                           6544.7                                   3574.9
# 53                            632.6                                     94.0
# 52                            909.6                                    196.8
# ..                              ...                                      ...
# 58                              NaN                                      NaN
# 57                              NaN                                      NaN
# 56                              NaN                                      NaN
# 69                              NaN                                      NaN
# 22                              NaN                                      NaN
#
#     payments orders  payments orders with internet  letter of credit  \
# 76           1037.6                          535.3               0.0
# 55             22.1                            8.1               0.0
# 54           4928.2                         3574.8               0.0
# 53            112.1                           93.9               0.0
# 52            499.9                          196.8               0.0
# ..              ...                            ...               ...
# 58              NaN                            NaN               NaN
# 57              NaN                            NaN               NaN
# 56              NaN                            NaN               NaN
# 69              NaN                            NaN               NaN
# 22              NaN                            NaN               NaN
#
#     payment requirements  payment requirements with internet  \
# 76                   0.1                                 0.0
# 55                   7.0                                 0.0
# 54                   8.4                                 0.1
# 53                   0.7                                 0.0
# 52                   3.1                                 0.0
# ..                   ...                                 ...
# 58                   NaN                                 NaN
# 57                   NaN                                 NaN
# 56                   NaN                                 NaN
# 69                   NaN                                 NaN
# 22                   NaN                                 NaN
#
#     collection orders  bank orders
# 76                4.1        476.7
# 55                0.4          0.1
# 54               45.0       1563.1
# 53                2.5        517.3
# 52               10.1        396.6
# ..                ...          ...
# 58                NaN          NaN
# 57                NaN          NaN
# 56                NaN          NaN
# 69                NaN          NaN
# 22                NaN          NaN
#
# [3576 rows x 11 columns]

# %% [markdown]
# # Index Construction

# %%
from scipy.stats import gmean

# %%
df = accounts_inst_remote_accounts_merged.copy()

df = df[~df["region"].isin(["Херсонская область", "Запорожская область", "Луганская Народная Республика", "Донецкая Народная Республика", "г. Севастополь", "Республика Крым"])]

corr_features = [
    "total_accounts",
    #"individual clients",
    # "additional offices",
    "total_in_credit_org",
    "number_of_new_remote_accounts_individuals_with_sms",
    "clients-legal entities that are not credit institutions",
    "number_of_new_remote_accounts",
    "number_of_new_remote_accounts_individuals_with_internet",
    "orders in electronic form total",
    "number_of_new_remote_accounts_individuals",
    "orders in electronic form with internet",
    "payments orders",
    "payment requirements",
    "bank orders"
    # "clients-legal entities that are not credit institutions",
    # "number_of_new_remote_accounts_individuals",
    # "clients-legal entities that are not credit institutions",
    # "number_of_new_remote_accounts",
    # "clients-legal entities that are not credit institutions",
    # "number_of_new_remote_accounts_individuals",
    # "number_of_new_remote_accounts_individuals",
    # "total_in_credit_org",
    # "additional offices",
    # "number_of_new_remote_accounts_individuals_with_internet"
]

df = df.drop(labels=corr_features, axis=1, errors="ignore")

# %%
df.select_dtypes("float").corr()
# Out:
#                                                     individual clients  \
# individual clients                                            1.000000
# The number of accounts opened by institutions o...            0.724989
# Total number of banking system institutions                   0.800199
# additional offices                                            0.864353
# Number of bank institutions per 1 million inhab...            0.022182
#
#                                                     The number of accounts opened by institutions of the banking system, per 1 resident, units.  \
# individual clients                                                                           0.724989
# The number of accounts opened by institutions o...                                           1.000000
# Total number of banking system institutions                                                  0.552856
# additional offices                                                                           0.629146
# Number of bank institutions per 1 million inhab...                                           0.072290
#
#                                                     Total number of banking system institutions  \
# individual clients                                                                     0.800199
# The number of accounts opened by institutions o...                                     0.552856
# Total number of banking system institutions                                            1.000000
# additional offices                                                                     0.974451
# Number of bank institutions per 1 million inhab...                                     0.233501
#
#                                                     additional offices  \
# individual clients                                            0.864353
# The number of accounts opened by institutions o...            0.629146
# Total number of banking system institutions                   0.974451
# additional offices                                            1.000000
# Number of bank institutions per 1 million inhab...            0.139501
#
#                                                     Number of bank institutions per 1 million inhabitants
# individual clients                                                                           0.022182
# The number of accounts opened by institutions o...                                           0.072290
# Total number of banking system institutions                                                  0.233501
# additional offices                                                                           0.139501
# Number of bank institutions per 1 million inhab...                                           1.000000

# %%
for col in df.drop(labels=["region", "date"], axis=1).columns:
    df[f'{col}_normalized'] = (
        df.groupby(['date'])[col]
        .transform(lambda x: (x - x.min()) / (x.max() - x.min()))
    )

# %%
def geometric_mean_no_zeros(row):
    # Отбираем только значения больше нуля
    positive_values = row[row > 0]
    if len(positive_values) == 0:  # Если все значения равны нулю
        return 0
    return gmean(positive_values)

df['geometric_mean'] = df[df.columns[df.columns.str.contains("_normalized")]].apply(geometric_mean_no_zeros, axis=1)

# %%
df = df.sort_values(by=["date", "region"])
df.index = df.date

# %%
pd.set_option("display.max_rows", 100)

# %%
df[(df["date"].dt.year == 2022) & (df["date"].dt.month == 10)].sort_values(by="geometric_mean", ascending=False)[["region", "geometric_mean"]]
# Out:
#                                        region  geometric_mean
# date
# 2022-10-01     г. Москва и Московская область        0.837992
# 2022-10-01                 г. Санкт-Петербург        0.261993
# 2022-10-01               Свердловская область        0.187763
# 2022-10-01                 Краснодарский край        0.187278
# 2022-10-01              Новосибирская область        0.178816
# 2022-10-01   Республика Татарстан (Татарстан)        0.170833
# 2022-10-01                  Тюменская область        0.170704
# 2022-10-01                Воронежская область        0.165006
# 2022-10-01                 Ростовская область        0.156558
# 2022-10-01                Челябинская область        0.145228
# 2022-10-01                  Самарская область        0.143539
# 2022-10-01              Нижегородская область        0.139553
# 2022-10-01                   Хабаровский край        0.124211
# 2022-10-01            Республика Башкортостан        0.120984
# 2022-10-01                    Приморский край        0.118619
# 2022-10-01                Ставропольский край        0.108033
# 2022-10-01                      Пермский край        0.105590
# 2022-10-01               Оренбургская область        0.099389
# 2022-10-01                Кемеровская область        0.095148
# 2022-10-01                  Красноярский край        0.094415
# 2022-10-01                  Иркутская область        0.086417
# 2022-10-01                     Алтайский край        0.086021
# 2022-10-01                Саратовская область        0.084930
# 2022-10-01                   Тульская область        0.083204
# 2022-10-01              Волгоградская область        0.081884
# 2022-10-01              Архангельская область        0.077876
# 2022-10-01                     Омская область        0.071088
# 2022-10-01                   Липецкая область        0.070673
# 2022-10-01                    Курская область        0.069382
# 2022-10-01           Республика Саха (Якутия)        0.068457
# 2022-10-01                    Республика Коми        0.065645
# 2022-10-01              Удмуртская Республика        0.064616
# 2022-10-01                  Орловская область        0.064529
# 2022-10-01                  Кировская область        0.063330
# 2022-10-01               Белгородская область        0.062217
# 2022-10-01                 Республика Бурятия        0.061998
# 2022-10-01                 Забайкальский край        0.060181
# 2022-10-01                Республика Мордовия        0.059595
# 2022-10-01                   Амурская область        0.058734
# 2022-10-01         Чукотский автономный округ        0.057698
# 2022-10-01                Вологодская область        0.055844
# 2022-10-01                  Калужская область        0.055181
# 2022-10-01                 Пензенская область        0.054922
# 2022-10-01                  Рязанская область        0.054332
# 2022-10-01                 Курганская область        0.053440
# 2022-10-01     Чувашская Республика - Чувашия        0.052931
# 2022-10-01                Ярославская область        0.052736
# 2022-10-01                Сахалинская область        0.051673
# 2022-10-01                   Брянская область        0.051250
# 2022-10-01                Ульяновская область        0.049823
# 2022-10-01            Калининградская область        0.049350
# 2022-10-01                 Республика Карелия        0.049186
# 2022-10-01               Владимирская область        0.049022
# 2022-10-01                 Смоленская область        0.048756
# 2022-10-01                  Псковская область        0.048209
# 2022-10-01               Новгородская область        0.048047
# 2022-10-01                   Тверская область        0.047923
# 2022-10-01                 Тамбовская область        0.046410
# 2022-10-01                 Мурманская область        0.045891
# 2022-10-01                 Ивановская область        0.045609
# 2022-10-01                Костромская область        0.043392
# 2022-10-01                    Томская область        0.042009
# 2022-10-01               Астраханская область        0.041428
# 2022-10-01                    Камчатский край        0.038409
# 2022-10-01                Республика Марий Эл        0.038367
# 2022-10-01                Магаданская область        0.035559
# 2022-10-01    Кабардино-Балкарская Республика        0.032364
# 2022-10-01         Республика Адыгея (Адыгея)        0.030184
# 2022-10-01                 Республика Хакасия        0.027982
# 2022-10-01                    Республика Тыва        0.027548
# 2022-10-01              Ленинградская область        0.024405
# 2022-10-01  Республика Северная Осетия-Алания        0.023120
# 2022-10-01       Еврейская автономная область        0.019844
# 2022-10-01                Республика Дагестан        0.018797
# 2022-10-01                Республика Калмыкия        0.018208
# 2022-10-01    Карачаево-Черкесская Республика        0.017214
# 2022-10-01                   Республика Алтай        0.017158
# 2022-10-01               Чеченская Республика        0.013881
# 2022-10-01               Республика Ингушетия        0.011324

# %%
df.region.unique()
# Out:
# array(['Алтайский край', 'Амурская область', 'Архангельская область',
#        'Астраханская область', 'Белгородская область', 'Брянская область',
#        'Владимирская область', 'Волгоградская область',
#        'Вологодская область', 'Воронежская область',
#        'Еврейская автономная область', 'Ивановская область',
#        'Иркутская область', 'Кабардино-Балкарская Республика',
#        'Калининградская область', 'Калужская область', 'Камчатский край',
#        'Карачаево-Черкесская Республика', 'Кемеровская область',
#        'Кировская область', 'Костромская область', 'Краснодарский край',
#        'Красноярский край', 'Курганская область', 'Курская область',
#        'Ленинградская область', 'Липецкая область', 'Магаданская область',
#        'Мурманская область', 'Нижегородская область',
#        'Новгородская область', 'Новосибирская область', 'Омская область',
#        'Оренбургская область', 'Орловская область', 'Пензенская область',
#        'Пермский край', 'Приморский край', 'Псковская область',
#        'Республика Адыгея (Адыгея)', 'Республика Алтай',
#        'Республика Башкортостан', 'Республика Бурятия',
#        'Республика Дагестан', 'Республика Ингушетия',
#        'Республика Калмыкия', 'Республика Карелия', 'Республика Коми',
#        'Республика Марий Эл', 'Республика Мордовия',
#        'Республика Саха (Якутия)', 'Республика Северная Осетия-Алания',
#        'Республика Татарстан (Татарстан)', 'Республика Тыва',
#        'Республика Хакасия', 'Ростовская область', 'Рязанская область',
#        'Самарская область', 'Саратовская область', 'Сахалинская область',
#        'Свердловская область', 'Смоленская область',
#        'Ставропольский край', 'Тамбовская область', 'Тверская область',
#        'Томская область', 'Тульская область', 'Тюменская область',
#        'Удмуртская Республика', 'Ульяновская область', 'Хабаровский край',
#        'Челябинская область', 'Чеченская Республика',
#        'Чувашская Республика - Чувашия', 'Чукотский автономный округ',
#        'Ярославская область', 'г. Москва и Московская область',
#        'г. Санкт-Петербург', 'Забайкальский край'], dtype=object)

# %%
df[df["region"] == "Забайкальский край"]["geometric_mean"].plot()
# Out:
# <Axes: xlabel='date'>
